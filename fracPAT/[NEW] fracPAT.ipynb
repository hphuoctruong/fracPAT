# %%
from general_settings import *

# %%
fn.plot(mesh, title='Mesh')
print('Degree of freedom: ', V.dim())
# Out:
# Degree of freedom:  3721

# %%
# x_opt = np.array([0., 0., 0., 0., 200./3.])
# x_opt = np.array([22.39571205, 46.41181807, 49.64768901, 43.89231014, 37.65247073])       # Optimized for I_0 = 200, alpha = 0.3, set 1, b = 10^(-4)
# x_opt = np.array([21.19567472, 48.72482769, 49.01709614, 42.92404163, 38.13835983])       # Optimized for I_0 = 250, alpha = 0.3, set 1
# x_opt = np.array([77.74421502, 52.81290923, 35.43391017, 23.57268236, 10.2286524])        # Optimized for I_0 = 200, alpha = 0.3, set 2
# x_opt = np.array([94.7705538 , 64.83091031, 44.19357984, 29.41601532, 14.55416751])       # Optimized for I_0 = 250, alpha = 0.3, set 2
x_opt = 10 * np.array([26.58514435, 43.45663502, 45.8251038 , 43.68162209, 40.45149474])         # Optimized for I_0 = 200, alpha = 0.3, set 1, b = 10^(-3)
# x_opt = np.array([ 66.1251,  51.9678, 0., -30.5733592, -51.3337421])                        # Optimized for I_0 = 200, alpha = 0.8
omega = np.array([20 * np.pi, 30 * np.pi, 40 * np.pi, 50 * np.pi, 60 * np.pi])
size_omega = len(omega)
list_i_prime_funcs = np.array([omega[i] * np.cos(omega[i] * simulation_times) for i in range(size_omega)])
i_true_time = x_opt.dot(list_i_prime_funcs)
f_true = space_time_mult(i_true_time, u_init, M_matrix, simulation_times)
# Zero vectors:
zero_vec = init_vector(M_matrix, 0)
zero_time_vec = init_time_vector(M_matrix, simulation_times, 0)

# %%
# Parameter:
c_expr = fn.Constant(c)
alpha = 0.3
# alpha = 0.8
b = (-(2 * c) / np.cos(np.pi * (alpha + 1)/ 2))
print(b)
# b = 31.54/1e3
b = 66.08/1e3
parameter = [c_expr, b, alpha]
# Out:
# 66.08067793755801

# %%
# Observation operator:
u_trial, u_test = fn.TrialFunction(V), fn.TestFunction(V)
B_matrix = fn.assemble(fn.inner(u_trial('+'), u_test('+')) * ds(1))
_misfit = WaveSpaceTimeStateObservation(V, simulation_times, simulation_times, B_matrix)

# Prior distribution:
gamma = 0.1
delta = 10.
_prior = BiLaplacianPrior(V, gamma, delta)
from WaveSolver import *
WaveNewModel = WaveInverseDamped(V, simulation_times, _misfit, _prior, parameter)

# %%
design = i_true_time
X_zero = WaveNewModel.generate_vector()
X_zero[PARAMETER][:] = u_init[:]
WaveNewModel.solveFwd(X_zero[STATE], X_zero, design)
WaveNewModel.misfit.p_obs = X_zero[STATE].copy()
WaveNewModel.misfit.noise_variance = 1e-2
parRandom.normal_perturb(WaveNewModel.misfit.noise_variance, WaveNewModel.misfit.p_obs)
print(WaveNewModel.cost(X_zero))
# Out:
# [0.006926886800562372, 0.005341632953806385, 0.0015852538467559867]

# %%
# Compute L2 norm of p_obs:
result = integrate_time_vectors(WaveNewModel.misfit.p_obs, WaveNewModel.misfit.p_obs, B_matrix, simulation_times)

# %%
from Jacobian import *
design = i_true_time
J_new = Jacobian_PAT(WaveNewModel, design)
H_new = Hessian_PAT(WaveNewModel, design)

# %%
k = 80
p = 20
print( "Single Pass Algorithm. Requested eigenvectors: {0}; Oversampling {1}.".format(k,p))
Omega = MultiVector(X_zero[PARAMETER], k + p)
parRandom.normal(1., Omega)
lmbda, Z = singlePassG(H_new, _prior.R, _prior.Rsolver, Omega, k)
_posterior = GaussianLRPosterior(_prior, lmbda, Z)
# Out:
# Single Pass Algorithm. Requested eigenvectors: 80; Oversampling 20.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.
# Solve forward problem.
# Solve adjoint problem.

# %%
X_iter_2 = WaveNewModel.generate_vector()
solution = np.load('data_function/bi_03_200_60init_103_NEWNEW.npy')
u_comp = init_vector_numpy(solution)
X_iter_2[PARAMETER][:] = u_comp[:]
SteinhaugSolver = CGSolverSteihaug()
SteinhaugSolver.set_operator(J_new)
SteinhaugSolver.set_preconditioner(_posterior.Hlr)
SteinhaugSolver.parameters["print_level"] = 1
SteinhaugSolver.parameters["rel_tolerance"] = 1e-4
SteinhaugSolver.parameters["abs_tolerance"] = 0.005
SteinhaugSolver.parameters["max_iter"] = 1000
SteinhaugSolver.parameters["zero_initial_guess"] = False
SteinhaugSolver.solve(X_iter_2[PARAMETER], J_new.M_b)
# Out:
#  Iteration :  0  (B r, r) =  0.06568772637628001
#  Iteration :  1  (B r, r) =  0.032259763290822446
#  Iteration :  2  (B r, r) =  0.02658165868738539
#  Iteration :  3  (B r, r) =  0.0193662176865798
#  Iteration :  4  (B r, r) =  0.01796836393450713
#  Iteration :  5  (B r, r) =  0.020445281498581772
#  Iteration :  6  (B r, r) =  0.02925520854065586
#  Iteration :  7  (B r, r) =  0.021772268596110953
#  Iteration :  8  (B r, r) =  0.02076159217645936
#  Iteration :  9  (B r, r) =  0.024538908398456755
#  Iteration :  10  (B r, r) =  0.024352219204066536
#  Iteration :  11  (B r, r) =  0.034902045958663225
#  Iteration :  12  (B r, r) =  0.025797525839509405
#  Iteration :  13  (B r, r) =  0.021106040028062205
#  Iteration :  14  (B r, r) =  0.02510464839447175
#  Iteration :  15  (B r, r) =  0.02448393733762598
#  Iteration :  16  (B r, r) =  0.018512913987763883
#  Iteration :  17  (B r, r) =  0.02438554378483344
#  Iteration :  18  (B r, r) =  0.018774584544231223
#  Iteration :  19  (B r, r) =  0.015557573933319233
#  Iteration :  20  (B r, r) =  0.01695330191772566
#  Iteration :  21  (B r, r) =  0.014364610987151385
#  Iteration :  22  (B r, r) =  0.011772134211139719
#  Iteration :  23  (B r, r) =  0.01214426164220473
#  Iteration :  24  (B r, r) =  0.01646474952793916
#  Iteration :  25  (B r, r) =  0.016693318553035526
#  Iteration :  26  (B r, r) =  0.015063492063820587
#  Iteration :  27  (B r, r) =  0.02084796254527632
#  Iteration :  28  (B r, r) =  0.013721155221736859
#  Iteration :  29  (B r, r) =  0.01522311179091861
#  Iteration :  30  (B r, r) =  0.013296610359914945
#  Iteration :  31  (B r, r) =  0.014194701106976659
#  Iteration :  32  (B r, r) =  0.008833765914809822
#  Iteration :  89  (B r, r) =  0.003630487893375844
#  Iteration :  90  (B r, r) =  0.005503535986379102
#  Iteration :  91  (B r, r) =  0.0041257119239916885
#  Iteration :  92  (B r, r) =  0.005154422022372262
#  Iteration :  93  (B r, r) =  0.0030971982524304427
#  Iteration :  94  (B r, r) =  0.0018685509902719424
#  Iteration :  95  (B r, r) =  0.002609158498204446
#  Iteration :  96  (B r, r) =  0.006514748024079261
#  Iteration :  97  (B r, r) =  0.004373839147261291
#  Iteration :  98  (B r, r) =  0.003750366132013988
#  Iteration :  99  (B r, r) =  0.005006172227396007
#  Iteration :  100  (B r, r) =  0.0048318201648166895
#  Iteration :  101  (B r, r) =  0.003263135455442572
#  Iteration :  102  (B r, r) =  0.0072415112138312825
#  Iteration :  103  (B r, r) =  0.004505692293182723
#  Iteration :  104  (B r, r) =  0.005863248560042626
#  Iteration :  105  (B r, r) =  0.005573515034629254
#  Iteration :  106  (B r, r) =  0.006333073754297891
#  Iteration :  107  (B r, r) =  0.004870936261446474
#  Iteration :  108  (B r, r) =  0.0028769765236007407
#  Iteration :  109  (B r, r) =  0.0034478931291253958
#  Iteration :  110  (B r, r) =  0.0019166295565757135
#  Iteration :  111  (B r, r) =  0.00402209583798472
#  Iteration :  112  (B r, r) =  0.003332117646662131
#  Iteration :  113  (B r, r) =  0.0015807001170146783
#  Iteration :  114  (B r, r) =  0.0014643203994924043
#  Iteration :  115  (B r, r) =  0.0024198728687495025
#  Iteration :  116  (B r, r) =  0.003018067595915
#  Iteration :  117  (B r, r) =  0.0019875083792028013
#  Iteration :  118  (B r, r) =  0.002563652615604477
#  Iteration :  119  (B r, r) =  0.0016628466928814154
#  Iteration :  120  (B r, r) =  0.002422406472136568
#  Iteration :  121  (B r, r) =  0.0021093746572813576
#  Iteration :  122  (B r, r) =  0.001471361352178541
#  Iteration :  123  (B r, r) =  0.0025677536391195445
#  Iteration :  124  (B r, r) =  0.0023235041236940525
#  Iteration :  125  (B r, r) =  0.0019942173103349435
#  Iteration :  126  (B r, r) =  0.001727397469244803
#  Iteration :  127  (B r, r) =  0.002655894421594872
#  Iteration :  128  (B r, r) =  0.001902227760972335
#  Iteration :  129  (B r, r) =  0.0014611239869658033
#  Iteration :  130  (B r, r) =  0.001628860701436718
#  Iteration :  131  (B r, r) =  0.0020856532494168355
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 13
#      11 SteinhaugSolver.parameters["max_iter"] = 1000
#      12 SteinhaugSolver.parameters["zero_initial_guess"] = False
# ---> 13 SteinhaugSolver.solve(X_iter_2[PARAMETER], J_new.M_b)
#
# File ~/Dropbox/Implementation/Python/PAT/utils/hippylib/algorithms/cgsolverSteihaug.py:259, in CGSolverSteihaug.solve(self, x, b)
#     256 self.d *= beta
#     257 self.d.axpy(1., self.z)  #d = z + beta d
# --> 259 self.A.mult(self.d,self.Ad)
#     261 den = self.d.inner(self.Ad)
#     263 if den <= 0.0:
#
# File ~/Dropbox/Implementation/Python/PAT/fracPAT/Jacobian.py:65, in Jacobian_PAT.mult(self, x, Jx)
#      63 X = [x_state, x, x_adj]
#      64 self.model.solveFwd(x_state, X, self.design)
# ---> 65 self.model.solveAdj(x_adj, X)
#      66 adj = self.model.computeAdj_old(X, self.design)
#      67 M_adj = self.M_matrix * adj
#
# File ~/Dropbox/Implementation/Python/PAT/fracPAT/WaveSolver.py:512, in WaveInverseDamped.solveAdj(self, out, X)
#     509 p_ddot_old = init_vector(self.M_matrix, 0)
#     510 p_temp = init_vector(self.M_matrix, 0)
# --> 512 p_time = time_vector_like(out)
#     513 p_dot_time = time_vector_like(out)
#     515 # Solve for t = T:
#     516 # print('Solve for t =', np.round(self.simulation_times[-1], 3))
#
# File ~/Dropbox/Implementation/Python/PAT/utils/functions.py:65, in time_vector_like(time_vector)
#      63 def time_vector_like(time_vector):
#      64     # Initialize a time-dependent vector that is compatible with the input time-dependent vector:
# ---> 65     new_time_vec = TimeDependentVector(time_vector.times, size=time_vector.data[0].size())
#      66     return new_time_vec
#
# File ~/Dropbox/Implementation/Python/PAT/utils/hippylib/modeling/timeDependentVector.py:40, in TimeDependentVector.__init__(self, times, tol, mpi_comm, size)
#      38 else:
#      39     for i in range(self.nsteps):
# ---> 40         self.data.append(dl.Vector(mpi_comm, size))
#      42 self.times = times
#      43 self.tol = tol
#
# KeyboardInterrupt:

# %%
diff = X_iter_2[PARAMETER] - X_zero[PARAMETER]
norm = np.sqrt(diff.inner(M_matrix * diff))
norm_zero = np.sqrt(X_zero[PARAMETER].inner(M_matrix * X_zero[PARAMETER]))
print('Relative L2 error: ', norm/norm_zero)
nb.plot(fn.Function(V, X_iter_2[PARAMETER]), colorbar=False, show_axis='on')
plt.colorbar(pad = 0.05)
plt.show()
# Out:
# Relative L2 error:  0.1765257592977753

# %%
# Export solution to numpy:
np.save('data_function/bi_03_200_60init_103_NEWNEW.npy', X_iter_2[PARAMETER][:])

# %%
# Check result:
solution = np.load('data_function/bi_08_200_opt_103.npy')
u_comp = init_vector_numpy(solution)
diff = u_comp - X_zero[PARAMETER]
norm_sub = np.sqrt(diff.inner(M_matrix_sub * diff))
norm_zero_sub = np.sqrt(X_zero[PARAMETER].inner(M_matrix_sub * X_zero[PARAMETER]))

norm_full = np.sqrt(diff.inner(M_matrix * diff))
norm_zero_full = np.sqrt(X_zero[PARAMETER].inner(M_matrix * X_zero[PARAMETER]))
# print('Relative L2 error sub : ', norm_sub /norm_zero_sub  * 100)
print('Relative L2 error full: ', norm_full/norm_zero_full * 100)
# Out:
# Relative L2 error full:  39.67799466947529

# %%
np.array([ 66.1251,  51.9678, 0., -30.5733592, -51.3337421])/200
# Out:
# array([ 0.3306255 ,  0.259839  ,  0.        , -0.1528668 , -0.25666871])

# %%
import numpy as np
x = np.array([86.26273311, 41.98872398, 29.45342825, 23.30126577, 18.99384889])/200
x = np.array([85.90138389, 41.95034421, 30.3213248 , 23.05318738, 18.77375973])/200
print(x)
# Out:
# [0.42950692 0.20975172 0.15160662 0.11526594 0.0938688 ]
